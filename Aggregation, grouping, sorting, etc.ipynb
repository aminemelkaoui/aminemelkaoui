# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("http://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
df.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
# 5         0       3                                    Mr. James Moran
# 6         0       1                             Mr. Timothy J McCarthy
# 7         0       3                      Master. Gosta Leonard Palsson
# 8         1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9         1       2                 Mrs. Nicholas (Adele Achem) Nasser
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# ...

# %%
df.tail()
# Out:
#      Survived  Pclass                            Name     Sex   Age  \
# 882         0       2            Rev. Juozas Montvila    male  27.0
# 883         1       1     Miss. Margaret Edith Graham  female  19.0
# 884         0       3  Miss. Catherine Helen Johnston  female   7.0
# 885         1       1            Mr. Karl Howell Behr    male  26.0
# 886         0       3              Mr. Patrick Dooley    male  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard   Fare
# 882                        0                        0  13.00
# 883                        0                        0  30.00
# 884                        1                        2  23.45
# 885                        0                        0  30.00
# 886                        0                        0   7.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare'],
#       dtype='object')

# %%
salair=df['Age']
salair
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 882    27.0
# 883    19.0
# 884     7.0
# 885    26.0
# 886    32.0
# Name: Age, Length: 887, dtype: float64

# %%
df.describe(include='all')
# Out:
#           Survived      Pclass               Name   Sex         Age  \
# count   887.000000  887.000000                887   887  887.000000
# unique         NaN         NaN                887     2         NaN
# top            NaN         NaN  Mr. Ivan Jalsevac  male         NaN
# freq           NaN         NaN                  1   573         NaN
# mean      0.385569    2.305524                NaN   NaN   29.471443
# std       0.487004    0.836662                NaN   NaN   14.121908
# min       0.000000    1.000000                NaN   NaN    0.420000
# 25%       0.000000    2.000000                NaN   NaN   20.250000
# 50%       0.000000    3.000000                NaN   NaN   28.000000
# 75%       1.000000    3.000000                NaN   NaN   38.000000
# max       1.000000    3.000000                NaN   NaN   80.000000
#
#         Siblings/Spouses Aboard  Parents/Children Aboard       Fare
# count                887.000000               887.000000  887.00000
# ...

# %% [markdown]
# ## QUESTION1

# %%
df[['Age','Fare']].describe()
# Out:
#               Age       Fare
# count  887.000000  887.00000
# mean    29.471443   32.30542
# std     14.121908   49.78204
# min      0.420000    0.00000
# 25%     20.250000    7.92500
# 50%     28.000000   14.45420
# 75%     38.000000   31.13750
# max     80.000000  512.32920

# %% [markdown]
# ## QUESTION2

# %%
df['Fare'].mean()
# Out:
# 32.30542018038328

# %%
df['Fare'].max()
# Out:
# 512.3292

# %%
df['Fare'].min()
# Out:
# 0.0

# %%
df['Fare'].idxmin()
# Out:
# 178

# %%
df['Fare'].idxmax()
# Out:
# 257

# %% [markdown]
# ## QUESTION31

# %%
df['Fare'].agg(['std','max','mean'])
# Out:
# std      49.78204
# max     512.32920
# mean     32.30542
# Name: Fare, dtype: float64

# %%
df[['Age','Fare']].agg(['skew','kurt','quantile'])
# Out:
#                 Age       Fare
# skew       0.447189   4.777671
# kurt       0.292559  33.264605
# quantile  28.000000  14.454200

# %% [markdown]
# ## QUESTION32

# %%
df[['Age','Fare']].agg(['skew','kurt','quantile'])
# Out:
#                 Age       Fare
# skew       0.447189   4.777671
# kurt       0.292559  33.264605
# quantile  28.000000  14.454200

# %%
df.skew(axis = 0, skipna = True)
# Out:
# Survived                   0.470999
# Pclass                    -0.623409
# Age                        0.447189
# Siblings/Spouses Aboard    3.686760
# Parents/Children Aboard    2.741198
# Fare                       4.777671
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.hist(df['Age'], color = 'blue', edgecolor = 'black')
# Out:
# (array([ 63.,  51., 242., 211., 142.,  88.,  49.,  28.,  11.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(df['Fare'], hist=True, kde=True, color = 'darkblue')

# %%
df_g_byAge = df.groupby('Sex')

# %%
df_g_byAge.groups
# Out:
# {'female': Int64Index([  1,   2,   3,   8,   9,  10,  11,  14,  15,  18,
#              ...
#              862, 867, 870, 871, 875, 876, 878, 881, 883, 884],
#             dtype='int64', length=314),
#  'male': Int64Index([  0,   4,   5,   6,   7,  12,  13,  16,  17,  20,
#              ...
#              869, 872, 873, 874, 877, 879, 880, 882, 885, 886],
#             dtype='int64', length=573)}

# %%
df_g_byAge.get_group('male')
# Out:
#      Survived  Pclass                           Name   Sex   Age  \
# 0           0       3         Mr. Owen Harris Braund  male  22.0
# 4           0       3        Mr. William Henry Allen  male  35.0
# 5           0       3                Mr. James Moran  male  27.0
# 6           0       1         Mr. Timothy J McCarthy  male  54.0
# 7           0       3  Master. Gosta Leonard Palsson  male   2.0
# ..        ...     ...                            ...   ...   ...
# 879         0       2   Mr. Frederick James Banfield  male  28.0
# 880         0       3          Mr. Henry Jr Sutehall  male  25.0
# 882         0       2           Rev. Juozas Montvila  male  27.0
# 885         1       1           Mr. Karl Howell Behr  male  26.0
# 886         0       3             Mr. Patrick Dooley  male  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0                          1                        0   7.2500
# ...

# %%
df_g_byAge.mean()
# Out:
#         Survived    Pclass        Age  Siblings/Spouses Aboard  \
# Sex
# female  0.742038  2.159236  27.719745                 0.694268
# male    0.190227  2.385689  30.431361                 0.432810
#
#         Parents/Children Aboard       Fare
# Sex
# female                 0.649682  44.479818
# male                   0.237347  25.633935

# %%
df.groupby(['Sex'])[['Age']].mean()
# Out:
#               Age
# Sex
# female  27.719745
# male    30.431361

# %%
df.groupby(['Sex']).mean()
# Out:
#         Survived    Pclass        Age  Siblings/Spouses Aboard  \
# Sex
# female  0.742038  2.159236  27.719745                 0.694268
# male    0.190227  2.385689  30.431361                 0.432810
#
#         Parents/Children Aboard       Fare
# Sex
# female                 0.649682  44.479818
# male                   0.237347  25.633935

# %%
df.groupby(['Age','Sex'])[['Fare']].mean()
# Out:
#                   Fare
# Age   Sex
# 0.42  male      8.5167
# 0.67  male     14.5000
# 0.75  female   19.2583
# 0.83  male     23.8750
# 0.92  male    151.5500
# ...                ...
# 70.00 male     40.7500
# 70.50 male      7.7500
# 71.00 male     42.0792
# 74.00 male      7.7750
# 80.00 male     30.0000
#
# [149 rows x 1 columns]

# %% [markdown]
# ## Q4

# %%
df.groupby(['Age','Sex'])[['Survived']].mean()
# Out:
#               Survived
# Age   Sex
# 0.42  male         1.0
# 0.67  male         1.0
# 0.75  female       1.0
# 0.83  male         1.0
# 0.92  male         1.0
# ...                ...
# 70.00 male         0.0
# 70.50 male         0.0
# 71.00 male         0.0
# 74.00 male         0.0
# 80.00 male         1.0
#
# [149 rows x 1 columns]

# %%
df_sorted= df.sort_values(by='Survived')
x,y=df_sorted.head(),df_sorted.tail()
y
# Out:
#      Survived  Pclass                              Name     Sex   Age  \
# 543         1       2  Mrs. Edward (Ethel Clarke) Beane  female  19.0
# 214         1       1            Miss. Madeleine Newell  female  31.0
# 215         1       3             Miss. Eliina Honkanen  female  27.0
# 217         1       1              Miss. Albina Bazzani  female  32.0
# 443         1       2  Miss. Madeleine Violet Mellinger  female  13.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard      Fare
# 543                        1                        0   26.0000
# 214                        1                        0  113.2750
# 215                        0                        0    7.9250
# 217                        0                        0   76.2917
# 443                        0                        1   19.5000

# %%
df.sort_values(by='Survived',ascending=False,inplace=True)
df.head()
# Out:
#      Survived  Pclass                                               Name  \
# 443         1       2                   Miss. Madeleine Violet Mellinger
# 338         1       2                      Master. Edmond Roger Navratil
# 335         1       1                     Miss. Elizabeth Margaret Burns
# 332         1       1  Mrs. Henry William (Clara Heinsheimer) Frauenthal
# 328         1       3                                  Miss. Agnes McCoy
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard    Fare
# 443  female  13.0                        0                        1   19.50
# 338    male   2.0                        1                        1   26.00
# 335  female  41.0                        0                        0  134.50
# 332  female  42.0                        1                        0  133.65
# 328  female  28.0                        2                        0   23.25

# %%
df.sort_index(axis=0,ascending=True,inplace=True)
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %% [markdown]
# ## Q6

# %%
df.sort_values(by='Survived',ascending=False,inplace=True)
df.head()
# Out:
#      Survived  Pclass                                               Name  \
# 443         1       2                   Miss. Madeleine Violet Mellinger
# 338         1       2                      Master. Edmond Roger Navratil
# 335         1       1                     Miss. Elizabeth Margaret Burns
# 332         1       1  Mrs. Henry William (Clara Heinsheimer) Frauenthal
# 328         1       3                                  Miss. Agnes McCoy
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard    Fare
# 443  female  13.0                        0                        1   19.50
# 338    male   2.0                        1                        1   26.00
# 335  female  41.0                        0                        0  134.50
# 332  female  42.0                        1                        0  133.65
# 328  female  28.0                        2                        0   23.25

# %%
df_sorted = df.sort_values(by= ['Survived','Age'],ascending=[False,True])
df_sorted.head()
# Out:
#      Survived  Pclass                            Name     Sex   Age  \
# 799         1       3  Master. Assad Alexander Thomas    male  0.42
# 751         1       2        Master. Viljo Hamalainen    male  0.67
# 641         1       3           Miss. Eugenie Baclini  female  0.75
# 466         1       3    Miss. Helene Barbara Baclini  female  0.75
# 827         1       2  Master. George Sibley Richards    male  0.83
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 799                        0                        1   8.5167
# 751                        1                        1  14.5000
# 641                        2                        1  19.2583
# 466                        2                        1  19.2583
# 827                        1                        1  18.7500
